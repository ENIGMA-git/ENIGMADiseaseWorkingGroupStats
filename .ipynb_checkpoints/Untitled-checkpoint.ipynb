# %%
import os
import pandas as pd

# %%
csv_path = os.path.join('config_examples', 'configure.csv')
config = pd.read_csv(csv_path)

# %%
config.to_html('config.html', index=False, classes=['table','table-striped','table-hover'])
